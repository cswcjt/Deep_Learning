# %% [markdown]
# <a href="https://colab.research.google.com/github/cswcjt/Deep_Learning/blob/main/02_BERTopic_practicel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bertopic

# %%
# !pip install konlpy pecab gensim
# !curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh | bash -x

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from tqdm.notebook import tqdm
# 형태소 분석기 불러오기
from konlpy.tag import Mecab; mecab = Mecab()
# CountVectorizer 불러오기 -> document-term matrix를 만들어주는 함수.
from sklearn.feature_extraction.text import CountVectorizer
# bertopic 불러오기
from bertopic import BERTopic

# %%
file_name = input("텍스트 파일 이름을 입력하세요 : ")
start_date = input("시작 날짜를 입력하세요 : ")
end_date = input("마지막 날짜를 입력하세요 : ")

# Colab Notebooks
data_path = '/content/drive/MyDrive/fastcamp/Deep_Learning/data'

# 아까 크롤링한 파일
## 크롤링한 파일이 바뀌면, 경로도 수정되어야 합니다.
data_path = f"{file_name}_({start_date}_{end_date}).xlsx"
# Out:
# 텍스트 파일 이름을 입력하세요 : 애플
# 시작 날짜를 입력하세요 : 2022.01.01
# 마지막 날짜를 입력하세요 : 2022.12.06

# %%
# data = pd.read_excel(base_path + data_path)
# /content/drive/MyDrive/fastcamp/Deep_Learning/data/애플_(2022.01.01_2022.12.06).xlsx

data = pd.read_excel("/content/drive/MyDrive/fastcamp/Deep_Learning/data/애플_(2022.01.01_2022.12.06).xlsx")
contents = data['contents'].dropna()
contents
# Out:
# 0       애플페이 도입에 ‘확인 불가’…소비자 ‘답답’MST 단말기 대부분인데…애플 NFC ...
# 1       기사내용 요약NFC 단말기 보조금 지급, 정보 유출 방지 대책 등 검토 필요    ...
# 2       [파이낸셜뉴스]       애플이 중국 이외 지역 생산 확대를 시도하는 가운데 지난...
# 3       위니아·위니아에이드 등 급등금감원 애플페이 약관심사 완료이르면 올해 안에 공식 출시...
# 4       애플페이, 비자에 이어 '세계 결제 규모 2위'    금융위, 애플페이 카드·전자금...
#                               ...
# 4669    [편집자주] '오미주'는 '오늘 주목되는 미국 주식'의 줄인 말입니다. 주가에 영향...
# 4670    애플, "9월 8일 아이폰14 공개" 발표크기 작은 '미니' 대신 화면 키운 '맥스...
# 4671    ■ 경제와이드 모닝벨 '글로벌 비즈' - 고유미 외신캐스터글로벌 비즈입니다.◇ 애플...
# 4672    올해 한국문학번역상 번역대상 수상자로 고은지와 마시 카라브레타 칸시오 벨로, 유신신...
# 4673    [편집자주] '오미주'는 '오늘 주목되는 미국 주식'의 줄인 말입니다. 주가에 영향...
# Name: contents, Length: 4662, dtype: object

# %%
p_contents = []
for doc in tqdm(contents):
    tokens = [token for token in mecab.morphs(doc) if len(token) > 1]
    p_contents.append(" ".join(tokens))

print(p_contents[0])
# Out:
#   0%|          | 0/4662 [00:00<?, ?it/s]
# 애플 페이 도입 확인 불가 ’… 소비자 답답 MST 단말기 대부분 인데 애플 NFC 단말기 도입 고수 AS 부실 결제 ’… 유독 시장 논란 애플 페이 이미지 사진 애플 애플 페이 뜨거운 감자 떠올랐 애플 현대 카드 손잡 해당 서비스 도입 추진 한다는 소식 전해 면서 소비자 관심 집중 지만 애플 묵묵부답 공식 입장 내놓 그간 한국 시장 찬밥 취급 한다는 비판 애플 다시 구설수 오른 이유 애플 애플 페이 한국 시장 도입 대해 확인 불가 입장 고수 도입 시기 11 30 예정 다는 소식 이미 나왔 지만 12 서비스 애플 관련 공식 입장 지만 답변 아이폰 국내 시장 점유 11 기준 30 %( 탯카운터 데이터 달한다 10 아이폰 이용 아이폰 유저 입장 에선 애플 페이 도입 단비 소식 애플 페이 해외 에서 대중 지만 한국 에선 이용 어려운 대표 서비스 꼽힌다 단말기 비용 애플 현대 카드 가맹점 줄다리기 애플 페이 대한 침묵 애플 고압 태도 근본 문제 시각 지배 모바일 결제 시스템 근거리 무선 통신 NFC 마그네 보안 전송 MST 으로 나뉜다 국내 시장 이미 마그네 저장 정보 무선 MST 자리 국내 대부분 신용 카드 가맹점 해당 방식 사용 삼성전자 역시 삼성 페이 시장 상황 반영 개발 반면 애플 NFC 방식 고수 단말기 보급 문제 떠오른 이유 애플 페이 국내 시장 안착 려면 업계 추산 3000 단말기 보급 투입 돼야 한다 애플 MST 방식 도입 입장 유지 분위기 비용 누가 감당 느냐 논의 지속 으로 전해진다 국내 NFC 단말기 보급 수준 일각 에선 소상 공인 해당 비용 부담 으로 애플 페이 도입 진행 다는 전망 NFC 지원 단말기 교체 비용 20 정도 만약 단말기 교체 비용 애플 이나 현대 카드 부담 으면 상공 입장 에선 부담 으로 작용 구조 서울 영등포 에서 카페 운영 45 학생 많이 에서 가게 운영 인데 대부분 아이폰 쓴다 만약 단말기 교체 필요 다면 겨자 심정 으로 비용 부담 해야 한다 지속 애플 고압 태도 시장 지배력 남용 애플 고압 태도 이번 애플 페이 도입 에서 나타난 문제 아니 애플 국내 입지 커지 여전히 폐쇄 시장 운영 정책 지속 때문 애플 시장 지배력 남용 한다는 지적 끊이 지난 애플 스토어 입점 발사 로부터 결제 수수료 과다 징수 다는 주장 제기 매출액 부가가치세 포함 계산 방식 으로 3500 달하 부당 이익 챙겼 다는 의혹 나왔 당시 국회 정무 위원회 소속 양정숙 의원 소속 해당 문제 언급 애플 관련 자료 요청 애플 여전히 묵묵부답 으로 일관 비판 목소리 공정거래위 원회 공정위 이후 해당 사안 대한 조사 진행 조사 결과 애플 스토어 입점 발사 로부터 부당 이익 취하 으로 나타났 애플 공정위 조사 문제 수수료 과다 부과 정책 2023 까지 시정 다는 입장 밝혔 애플 사후 관리 서비스 AS 문제 지적 된다 한국 소비 자원 따르 최근 2019 2021 애플 제품 AS 관련 접수 소비자 불만 건수 165 전체 정보 통신 기기 AS 불만 접수 건수 659 고려 불만 애플 제품 연관 165 106 64 %) 소비자 애플 원만 합의 이르 못한 으로 나타났 애플 이용자 보호 정책 방송 통신 위원회 전기 통신 사업자 이용자 보호 업무 평가 마켓 분야 에서 애플 연속 하위 미흡 등급 결제 논란 으로 이용자 보호 부족 지적 반영 결과

# %% [markdown]
# Source : https://www.sbert.net/docs/pretrained_models.html

# %%
vectorizer = CountVectorizer(max_features=3000) # 빈도가 높은 3000개만 사용.

# sentence-transformer에 있는 pretrained model 사용 가능.
model = BERTopic(embedding_model='paraphrase-multilingual-mpnet-base-v2', # pretrained-model
                 vectorizer_model=vectorizer, # vectorizer
                 nr_topics=5,  # num_topics
                 top_n_words=30, # top_n_words
                 calculate_probabilities=True)

# %%
topics, probs = model.fit_transform(p_contents) # dtm
# Out:
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.77k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/723 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/402 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
# Intertopic Distance Map
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2eaf8cbe-c592-46b5-8175-a934fe1aef97" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2